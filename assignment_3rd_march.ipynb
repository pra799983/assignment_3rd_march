# %%
#  Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

1. Line Plot
2. Bar Chart
3. Pairplot
4. Scatter Plot
5. Histogram

1. Line Plot-->>>>>>>
A Line Plot Is The Simplest Plot In All Plotting Types, As It Is The Visualization Of A Single Function. 
This Plot Helps Us To See The Relationship Between X-Axis, Y-Axis And It Also Takes Some Parameters Such As Hue, Size, Color, Etc.  

2. Bar Plot -->>>>>>>
A Bar Chart Is A Way Of Comparing A Set Of Categorical Data. It Is Better To Convert Continuous Data To Bins Before Plotting. 
The Bar Chart Displays Data
Using Several Bars, Each Representing A Particular Category. This Method Is Accepting The Parameters X, Y  
Which Take The Name Of A Variable In Data, Hue It Is An Optional Parameter It Helps To Take Column Name For Color Encoding.


3. Pair Plot -->>>>>>>
Pair Plot Creates A Grid Of Axis Such That Each Numeric Variable In Data Will Create A Plot Between Each Other 
The Y-Axis Across A Single Row And The X-Axis Across A Single Column. The Diagonal Plots Are A Univariate Distribution Plot 
That Helps To Draw The Marginal Distribution Of The Data In Each Column.

A Pair Plot Pairwise Relationships With Other Columns In The Data Frame And Also Plot Pair Plot With Itself.

4. Scatter Plot  -->>>>>>>
Scatter Plot Is The Same As A Line Plot, In A Line Plot Instead Of Points Being Joined By Line Segments, 
The Points Are Shown Individually With A Dot, Circle, Or Any Other Shape. The Position Of Each Marker On The Horizontal And 
Vertical Axis Indicates Values For An Individual Data Point. This Plot Is Used To Observe Relationships Between Variables.

This Method Is Accepting The Parameters X, Y  Which Take The Name Of A Variable In Data, Hue It Is An Optional Parameter 
It Helps To Take Column Name For Color Encoding.
Marker Is A Parameter That Is Used To Change The Shape Of The Point Which Is Shown In The Plot.

5. Histogram -->>>>>>>
A Histogram Is A Graph That Shows The Underlying Frequency Distribution Of A Set Of Continuous Data. 
This Chart Is Helpful In Data Collection And Data Analysis And Hence It Is Widely Used In The Analytics Industry. 
By Plotting It Allows To Inspect The Overall Distribution Of The Data, Outlier, Skew Present In The Data.

# %%
# Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using 
#    x =  "timepoint" and y = "signal" for different events and regions.
#     Note: timepoint, signal, event, and region are columns in the fmri dataset.

import seaborn as sns
fmri = sns.load_dataset('fmri')
sns.lineplot(x = fmri.timepoint, y =fmri.signal)
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
# Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
#         'pclass', y = 'age' and y = 'fare'.
#          Note: pclass, age, and fare are columns in the titanic dataset.
  
import seaborn as sns
titanic = sns.load_dataset('titanic')
sns.boxplot(x = titanic.pclass,y = titanic.age)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='age'>

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
sns.boxplot(x = titanic.pclass,y = titanic.fare)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
#     parameter for the 'cut' column of the diamonds dataset.

import seaborn as sns
diamonds = sns.load_dataset('diamonds')
sns.histplot(diamonds['price'])
# Out:
# <AxesSubplot: xlabel='price', ylabel='Count'>

# %%
import seaborn as sns
diamonds = sns.load_dataset('diamonds')
sns.histplot(x  = 'x',y = 'y',data = diamonds,hue = 'cut')
# Out:
# <AxesSubplot: xlabel='x', ylabel='y'>

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
# Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
#      of the iris dataset.

import seaborn as sns
iris = sns.load_dataset('iris')

# %%
sns.pairplot( data = iris,hue = 'species')

# %%
# Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

import seaborn as sns
flights = sns.load_dataset('flights').pivot('month','year','passengers')
sns.heatmap( flights,annot = True)
# Out:
# /tmp/ipykernel_214/835903225.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = sns.load_dataset('flights').pivot('month','year','passengers')
# <AxesSubplot: xlabel='year', ylabel='month'>

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
